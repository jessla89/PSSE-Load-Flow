# %%
import pandas as pd
import numpy as np

# %%
f = open("new_9.csv", "r")
data_new = f.read()

# %%
header_string = data_new.split('\n')[0]

# %%
header = header_string.split(';')

# %%
info_string_list = data_new.split('\n')[1:]

# %%
info_list = []

# %%
for each_string in info_string_list:
    info_list.append(each_string.split(';'))

# %%
df = pd.DataFrame(info_list)
df.columns = header

# %%
df
# Out:
#                           Bus Name Area Number Zone Number Volt (PU)  \
# 0       101     NUC-A       21.600           1          77    1.0200
# 1                                            0           0    0.0000
# 2       102     NUC-B       21.600           1          77    1.0200
# 3                                            0           0    0.0000
# 4       151     NUCPANT     500.00           1           1    1.0060
# .. ..                          ...         ...         ...       ...
# 81     3011     MINE_G      13.800           5           5    1.0400
# 82                                           0           0    0.0000
# 83     3018     CATDOG_G    13.800           5           5    0.9684
# 84                                           0           0    0.0000
# 85                            None        None        None      None
#
#    Volt (KV) Angle (Deg)    Gen MW  Gen MVAR Load MW Load MVAR Shunt MW  \
# 0    22.0320      1.6322  750.0000  125.2095  0.0000    0.0000   0.0000
# 1     0.0000      0.0000    0.0000    0.0000  0.0000    0.0000   0.0000
# 2    22.0320      1.6322  750.0000  125.2095  0.0000    0.0000   0.0000
# 3     0.0000      0.0000    0.0000    0.0000  0.0000    0.0000   0.0000
# 4   503.0226     -4.0513    0.0000    0.0000  0.0000    0.0000   0.0000
# ..       ...         ...       ...       ...     ...       ...      ...
# 81   14.3520      0.0000  843.7432  309.6772  0.0000    0.0000   0.0000
# 82    0.0000      0.0000    0.0000    0.0000  0.0000    0.0000   0.0000
# 83   13.3640    -18.6719  100.0000   80.0000  0.0000    0.0000   0.0000
# 84    0.0000      0.0000    0.0000    0.0000  0.0000    0.0000   0.0000
# 85      None        None      None      None    None      None     None
#
#    Shunt MVAR                          To Bus Name        MW      MVAR  \
# 0     -0.0000                                         0.0000    0.0000
# 1      0.0000   151     NUCPANT     500.00    1  1  749.9995  125.2095
# 2     -0.0000                                         0.0000    0.0000
# 3      0.0000   151     NUCPANT     500.00    1  1  749.9995  125.2095
# 4    607.2761                                         0.0000    0.0000
# ..        ...                                  ...       ...       ...
# 81    -0.0000                                         0.0000    0.0000
# 82     0.0000  3001     MINE        230.00    5  1  843.7432  309.6772
# 83    -0.0000                                         0.0000    0.0000
# 84     0.0000  3008     CATDOG      230.00    5  1   99.9977   79.9993
# 85       None                                 None      None      None
#
#    Transformer Ratio Transformer Angle (Deg) Percent Rating
# 0                                     0.0000       0
# 1            1.000UN                  0.0000      61   1250
# 2                                     0.0000       0
# 3            1.000UN                  0.0000      61   1250
# 4                                     0.0000       0
# ..               ...                     ...     ...    ...
# 81                                    0.0000       0
# 82           1.000UN                  0.0000      69   1300
# 83                                    0.0000       0
# 84           1.000UN                  0.0000      85    150
# 85              None                    None    None   None
#
# [86 rows x 20 columns]

# %%
df = df.drop(index = (len(df) -1))

# %%
df
# Out:
#                           Bus Name Area Number Zone Number Volt (PU)  \
# 0       101     NUC-A       21.600           1          77    1.0200
# 1                                            0           0    0.0000
# 2       102     NUC-B       21.600           1          77    1.0200
# 3                                            0           0    0.0000
# 4       151     NUCPANT     500.00           1           1    1.0060
# .. ..                          ...         ...         ...       ...
# 80                                           0           0    0.0000
# 81     3011     MINE_G      13.800           5           5    1.0400
# 82                                           0           0    0.0000
# 83     3018     CATDOG_G    13.800           5           5    0.9684
# 84                                           0           0    0.0000
#
#    Volt (KV) Angle (Deg)    Gen MW  Gen MVAR Load MW Load MVAR Shunt MW  \
# 0    22.0320      1.6322  750.0000  125.2095  0.0000    0.0000   0.0000
# 1     0.0000      0.0000    0.0000    0.0000  0.0000    0.0000   0.0000
# 2    22.0320      1.6322  750.0000  125.2095  0.0000    0.0000   0.0000
# 3     0.0000      0.0000    0.0000    0.0000  0.0000    0.0000   0.0000
# 4   503.0226     -4.0513    0.0000    0.0000  0.0000    0.0000   0.0000
# ..       ...         ...       ...       ...     ...       ...      ...
# 80    0.0000      0.0000    0.0000    0.0000  0.0000    0.0000   0.0000
# 81   14.3520      0.0000  843.7432  309.6772  0.0000    0.0000   0.0000
# 82    0.0000      0.0000    0.0000    0.0000  0.0000    0.0000   0.0000
# 83   13.3640    -18.6719  100.0000   80.0000  0.0000    0.0000   0.0000
# 84    0.0000      0.0000    0.0000    0.0000  0.0000    0.0000   0.0000
#
#    Shunt MVAR                          To Bus Name        MW      MVAR  \
# 0     -0.0000                                         0.0000    0.0000
# 1      0.0000   151     NUCPANT     500.00    1  1  749.9995  125.2095
# 2     -0.0000                                         0.0000    0.0000
# 3      0.0000   151     NUCPANT     500.00    1  1  749.9995  125.2095
# 4    607.2761                                         0.0000    0.0000
# ..        ...                                  ...       ...       ...
# 80     0.0000  3018     CATDOG_G    13.800    5  1  -99.9610  -65.1355
# 81    -0.0000                                         0.0000    0.0000
# 82     0.0000  3001     MINE        230.00    5  1  843.7432  309.6772
# 83    -0.0000                                         0.0000    0.0000
# 84     0.0000  3008     CATDOG      230.00    5  1   99.9977   79.9993
#
#    Transformer Ratio Transformer Angle (Deg) Percent Rating
# 0                                     0.0000       0
# 1            1.000UN                  0.0000      61   1250
# 2                                     0.0000       0
# 3            1.000UN                  0.0000      61   1250
# 4                                     0.0000       0
# ..               ...                     ...     ...    ...
# 80           1.000LK                  0.0000      80    150
# 81                                    0.0000       0
# 82           1.000UN                  0.0000      69   1300
# 83                                    0.0000       0
# 84           1.000UN                  0.0000      85    150
#
# [85 rows x 20 columns]

# %%
df['Bus Name'] = df['Bus Name'].replace(r'^\s*$', np.nan, regex=True).ffill()

# %%
# df.to_csv('lout_2.csv')

# %%
df
# Out:
#                           Bus Name Area Number Zone Number Volt (PU)  \
# 0       101     NUC-A       21.600           1          77    1.0200
# 1       101     NUC-A       21.600           0           0    0.0000
# 2       102     NUC-B       21.600           1          77    1.0200
# 3       102     NUC-B       21.600           0           0    0.0000
# 4       151     NUCPANT     500.00           1           1    1.0060
# .. ..                          ...         ...         ...       ...
# 80     3008     CATDOG      230.00           0           0    0.0000
# 81     3011     MINE_G      13.800           5           5    1.0400
# 82     3011     MINE_G      13.800           0           0    0.0000
# 83     3018     CATDOG_G    13.800           5           5    0.9684
# 84     3018     CATDOG_G    13.800           0           0    0.0000
#
#    Volt (KV) Angle (Deg)    Gen MW  Gen MVAR Load MW Load MVAR Shunt MW  \
# 0    22.0320      1.6322  750.0000  125.2095  0.0000    0.0000   0.0000
# 1     0.0000      0.0000    0.0000    0.0000  0.0000    0.0000   0.0000
# 2    22.0320      1.6322  750.0000  125.2095  0.0000    0.0000   0.0000
# 3     0.0000      0.0000    0.0000    0.0000  0.0000    0.0000   0.0000
# 4   503.0226     -4.0513    0.0000    0.0000  0.0000    0.0000   0.0000
# ..       ...         ...       ...       ...     ...       ...      ...
# 80    0.0000      0.0000    0.0000    0.0000  0.0000    0.0000   0.0000
# 81   14.3520      0.0000  843.7432  309.6772  0.0000    0.0000   0.0000
# 82    0.0000      0.0000    0.0000    0.0000  0.0000    0.0000   0.0000
# 83   13.3640    -18.6719  100.0000   80.0000  0.0000    0.0000   0.0000
# 84    0.0000      0.0000    0.0000    0.0000  0.0000    0.0000   0.0000
#
#    Shunt MVAR                          To Bus Name        MW      MVAR  \
# 0     -0.0000                                         0.0000    0.0000
# 1      0.0000   151     NUCPANT     500.00    1  1  749.9995  125.2095
# 2     -0.0000                                         0.0000    0.0000
# 3      0.0000   151     NUCPANT     500.00    1  1  749.9995  125.2095
# 4    607.2761                                         0.0000    0.0000
# ..        ...                                  ...       ...       ...
# 80     0.0000  3018     CATDOG_G    13.800    5  1  -99.9610  -65.1355
# 81    -0.0000                                         0.0000    0.0000
# 82     0.0000  3001     MINE        230.00    5  1  843.7432  309.6772
# 83    -0.0000                                         0.0000    0.0000
# 84     0.0000  3008     CATDOG      230.00    5  1   99.9977   79.9993
#
#    Transformer Ratio Transformer Angle (Deg) Percent Rating
# 0                                     0.0000       0
# 1            1.000UN                  0.0000      61   1250
# 2                                     0.0000       0
# 3            1.000UN                  0.0000      61   1250
# 4                                     0.0000       0
# ..               ...                     ...     ...    ...
# 80           1.000LK                  0.0000      80    150
# 81                                    0.0000       0
# 82           1.000UN                  0.0000      69   1300
# 83                                    0.0000       0
# 84           1.000UN                  0.0000      85    150
#
# [85 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0                            85 non-null     object
#  1   Bus Name                 85 non-null     object
#  2   Area Number              85 non-null     object
#  3   Zone Number              85 non-null     object
#  4   Volt (PU)                85 non-null     object
#  5   Volt (KV)                85 non-null     object
#  6   Angle (Deg)              85 non-null     object
#  7   Gen MW                   85 non-null     object
#  8   Gen MVAR                 85 non-null     object
#  9   Load MW                  85 non-null     object
#  10  Load MVAR                85 non-null     object
#  11  Shunt MW                 85 non-null     object
#  12  Shunt MVAR               85 non-null     object
#  13  To Bus Name              85 non-null     object
#  14  MW                       85 non-null     object
#  15  MVAR                     85 non-null     object
#  16  Transformer Ratio        85 non-null     object
#  17  Transformer Angle (Deg)  85 non-null     object
#  18  Percent                  85 non-null     object
#  19  Rating                   85 non-null     object
# dtypes: object(20)
# memory usage: 13.4+ KB

# %%
data_updated = df.drop(columns = [''])

# %%
data_updated.columns
# Out:
# Index(['Bus Name', 'Area Number', 'Zone Number', 'Volt (PU)', 'Volt (KV)',
#        'Angle (Deg)', 'Gen MW', 'Gen MVAR', 'Load MW', 'Load MVAR', 'Shunt MW',
#        'Shunt MVAR', 'To Bus Name', 'MW', 'MVAR', 'Transformer Ratio',
#        'Transformer Angle (Deg)', 'Percent', 'Rating', 'Load Flow Case'],
#       dtype='object')

# %%
data_updated['Load Flow Case'] = 'Load-MW = 3749.3093, Gen-MW = 3843.7, Reactors-Mvar = 600, Capacitors-Mvar = 950, Load-Mvar = 1950'

# %%
data_updated.columns
# Out:
# Index(['Bus Name', 'Area Number', 'Zone Number', 'Volt (PU)', 'Volt (KV)',
#        'Angle (Deg)', 'Gen MW', 'Gen MVAR', 'Load MW', 'Load MVAR', 'Shunt MW',
#        'Shunt MVAR', 'To Bus Name', 'MW', 'MVAR', 'Transformer Ratio',
#        'Transformer Angle (Deg)', 'Percent', 'Rating', 'Load Flow Case'],
#       dtype='object')

# %%
data_updated.to_csv('case_9.csv')
